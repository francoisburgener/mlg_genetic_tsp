# %%
from pyevolve import G1DList
from pyevolve import GSimpleGA
from pyevolve import Selectors
from pyevolve import Statistics

# %%
def fitness(chromosome):
    score = 0.0
    target = 'METHINKS_IT_IS_LIKE_A_WEASEL'
    # iterate over the chromosome
    for i in range(0,len(chromosome)):
        if chr(chromosome[i]) == target[i]:
            score += 1
    return score

# %%
def current_best(ga_engine):
    # Here you have access to the GA Engine
    best = ga.bestIndividual()
    for i in range(0,len(best)):
        print(chr(best[i]))
    return False

# %%
# Chromosome representation

# genome = List of elements
genome = G1DList.G1DList(28)

# elements = values in the range rangemin and rangemax
# ASCII(65) = 'A' .... ASCII(95) = '_'
genome.setParams(rangemin=65, rangemax=95)

# how to compute the fitness
genome.evaluator.set(fitness)

# GA initialisation
ga = GSimpleGA.GSimpleGA(genome)
ga.setPopulationSize(200)
ga.setMutationRate(0.05)
ga.setCrossoverRate(0.9)
ga.selector.set(Selectors.GTournamentSelector)
ga.setElitism(True)

# Number of generations
ga.setGenerations(500)

# In case we want to monitor the evolution process
# execute the function current_best every generation
#ga.stepCallback.set(current_best)

ga.evolve(freq_stats=10)

# Final best solution
best = ga.bestIndividual()

for i in range(0,len(best)):
    print(chr(best[i]))
# Out:
# Gen. 0 (0.00%): Max/Min/Avg Fitness(Raw) [1.18(5.00)/0.94(0.00)/0.99(0.98)]
# Gen. 10 (2.00%): Max/Min/Avg Fitness(Raw) [7.99(11.00)/5.23(2.00)/6.66(6.66)]
# Gen. 20 (4.00%): Max/Min/Avg Fitness(Raw) [13.78(17.00)/10.03(8.00)/11.48(11.48)]
# Gen. 30 (6.00%): Max/Min/Avg Fitness(Raw) [16.32(18.00)/11.37(10.00)/13.60(13.60)]
# Gen. 40 (8.00%): Max/Min/Avg Fitness(Raw) [17.74(20.00)/11.50(9.00)/14.79(14.79)]
# Gen. 50 (10.00%): Max/Min/Avg Fitness(Raw) [19.28(23.00)/13.72(11.00)/16.06(16.07)]
# Gen. 60 (12.00%): Max/Min/Avg Fitness(Raw) [21.28(23.00)/15.22(14.00)/17.73(17.73)]
# Gen. 70 (14.00%): Max/Min/Avg Fitness(Raw) [21.73(24.00)/15.58(14.00)/18.11(18.11)]
# Gen. 80 (16.00%): Max/Min/Avg Fitness(Raw) [23.49(26.00)/16.79(15.00)/19.58(19.57)]
# Gen. 90 (18.00%): Max/Min/Avg Fitness(Raw) [23.35(27.00)/17.16(15.00)/19.46(19.46)]
# Gen. 100 (20.00%): Max/Min/Avg Fitness(Raw) [22.85(27.00)/17.11(15.00)/19.05(19.05)]
# Gen. 110 (22.00%): Max/Min/Avg Fitness(Raw) [23.52(27.00)/17.16(15.00)/19.60(19.60)]
# Gen. 120 (24.00%): Max/Min/Avg Fitness(Raw) [23.57(27.00)/17.16(15.00)/19.64(19.64)]
# Gen. 130 (26.00%): Max/Min/Avg Fitness(Raw) [23.11(27.00)/17.14(15.00)/19.26(19.25)]
# Gen. 140 (28.00%): Max/Min/Avg Fitness(Raw) [23.15(27.00)/17.14(15.00)/19.29(19.29)]
# Gen. 150 (30.00%): Max/Min/Avg Fitness(Raw) [23.57(27.00)/16.63(14.00)/19.64(19.64)]
# Gen. 160 (32.00%): Max/Min/Avg Fitness(Raw) [23.29(27.00)/17.67(16.00)/19.40(19.41)]
# Gen. 170 (34.00%): Max/Min/Avg Fitness(Raw) [23.34(27.00)/17.16(15.00)/19.45(19.45)]
# Gen. 180 (36.00%): Max/Min/Avg Fitness(Raw) [23.13(27.00)/16.64(14.00)/19.27(19.27)]
# Gen. 190 (38.00%): Max/Min/Avg Fitness(Raw) [23.75(27.00)/17.16(15.00)/19.79(19.79)]
# Gen. 200 (40.00%): Max/Min/Avg Fitness(Raw) [23.23(27.00)/16.64(14.00)/19.36(19.36)]
# Gen. 210 (42.00%): Max/Min/Avg Fitness(Raw) [23.86(27.00)/17.71(16.00)/19.88(19.88)]
# Gen. 220 (44.00%): Max/Min/Avg Fitness(Raw) [23.14(27.00)/16.64(14.00)/19.29(19.29)]
# Gen. 230 (46.00%): Max/Min/Avg Fitness(Raw) [23.05(27.00)/17.13(15.00)/19.21(19.20)]
# Gen. 240 (48.00%): Max/Min/Avg Fitness(Raw) [24.19(27.00)/17.71(16.00)/20.15(20.16)]
# Gen. 250 (50.00%): Max/Min/Avg Fitness(Raw) [23.11(27.00)/16.64(14.00)/19.26(19.25)]
# Gen. 260 (52.00%): Max/Min/Avg Fitness(Raw) [23.13(27.00)/16.64(14.00)/19.27(19.27)]
# Gen. 270 (54.00%): Max/Min/Avg Fitness(Raw) [23.59(27.00)/17.16(15.00)/19.65(19.66)]
# Gen. 280 (56.00%): Max/Min/Avg Fitness(Raw) [23.41(27.00)/17.16(15.00)/19.51(19.51)]
# Gen. 290 (58.00%): Max/Min/Avg Fitness(Raw) [22.63(27.00)/16.61(14.00)/18.86(18.86)]
# Gen. 300 (60.00%): Max/Min/Avg Fitness(Raw) [23.10(27.00)/17.14(15.00)/19.25(19.25)]
# Gen. 310 (62.00%): Max/Min/Avg Fitness(Raw) [23.85(27.00)/17.16(15.00)/19.87(19.88)]
# Gen. 320 (64.00%): Max/Min/Avg Fitness(Raw) [24.25(27.00)/18.30(17.00)/20.21(20.21)]
# Gen. 330 (66.00%): Max/Min/Avg Fitness(Raw) [22.77(27.00)/17.10(15.00)/18.97(18.98)]
# Gen. 340 (68.00%): Max/Min/Avg Fitness(Raw) [23.45(27.00)/17.16(15.00)/19.54(19.55)]
# Gen. 350 (70.00%): Max/Min/Avg Fitness(Raw) [23.99(27.00)/17.71(16.00)/20.00(20.00)]
# Gen. 360 (72.00%): Max/Min/Avg Fitness(Raw) [23.02(27.00)/16.64(14.00)/19.18(19.18)]
# Gen. 370 (74.00%): Max/Min/Avg Fitness(Raw) [23.69(27.00)/17.16(15.00)/19.74(19.74)]
# Gen. 380 (76.00%): Max/Min/Avg Fitness(Raw) [23.48(27.00)/17.16(15.00)/19.57(19.57)]
# Gen. 390 (78.00%): Max/Min/Avg Fitness(Raw) [23.46(27.00)/16.64(14.00)/19.55(19.55)]
# Gen. 400 (80.00%): Max/Min/Avg Fitness(Raw) [23.69(27.00)/17.16(15.00)/19.75(19.75)]
# Gen. 410 (82.00%): Max/Min/Avg Fitness(Raw) [23.23(27.00)/17.15(15.00)/19.36(19.36)]
# Gen. 420 (84.00%): Max/Min/Avg Fitness(Raw) [23.29(27.00)/17.67(16.00)/19.41(19.41)]
# Gen. 430 (86.00%): Max/Min/Avg Fitness(Raw) [22.52(27.00)/16.14(13.00)/18.76(18.77)]
# Gen. 440 (88.00%): Max/Min/Avg Fitness(Raw) [22.97(27.00)/17.12(15.00)/19.14(19.14)]
# Gen. 450 (90.00%): Max/Min/Avg Fitness(Raw) [23.01(27.00)/17.13(15.00)/19.17(19.18)]
# Gen. 460 (92.00%): Max/Min/Avg Fitness(Raw) [23.74(27.00)/17.16(15.00)/19.79(19.79)]
# Gen. 470 (94.00%): Max/Min/Avg Fitness(Raw) [23.20(27.00)/17.15(15.00)/19.33(19.34)]
# Gen. 480 (96.00%): Max/Min/Avg Fitness(Raw) [22.88(27.00)/17.11(15.00)/19.07(19.07)]
# Gen. 490 (98.00%): Max/Min/Avg Fitness(Raw) [23.94(27.00)/17.15(15.00)/19.95(19.95)]
# Gen. 500 (100.00%): Max/Min/Avg Fitness(Raw) [23.53(27.00)/17.69(16.00)/19.61(19.61)]
# Total time elapsed: 14.011 seconds.
# M
# E
# T
# _
# I
# N
# K
# S
# _
# I
# T
# _
# I
# S
# _
# L
# I
# K
# E
# _
# A
# _
# W
# E
# A
# S
# E
# L
